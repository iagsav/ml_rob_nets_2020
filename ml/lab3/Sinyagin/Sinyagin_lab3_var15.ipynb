# %% [markdown]
# ### ФИО студента: Синягин Илья
#
# ### Группа: 18-ИВТ-3
#
# ### Вариант: 15
#
# ### Задание: Air quality

# %% [markdown]
# 1. Изучить набор данных. Создать описание набора данных на русском языке. Описать признаки, используемые в наборе данных (включить полученные описания в отчёт).
# 2. Удалите дубликаты строк в наборе данных; приведите размер набора данных до и после данной операции;
# 3. Выполните масштабирование количественных признаков; Постройте диаграммы BoxPlot для признаков до и после масштабирования. Выберите способ масштабирования (например, нормализацию или стандартизацию);
# 4. Выполните замену категориальных признаков; выберите и обоснуйте способ замены;
# 5. Оцените корреляцию между признаков и удалите те признаки, которые коррелируют с наибольшим числом других;
# 6. Заполните пропущенные значения в данных;
# 7. Решите поставленную задачу регрессии в соответствии с заданием. При подборе параметров метода принятия решения (метода регрессии) используйте перекрёстную проверку (изучите возможные для изменения параметры метода регрессии).  Вычислите точность решения задачи, вычислив разницу между реальным значением и предсказанным. Вычислите коэффициент корреляции (Пирсона, Спирмена) между реальным значением и предсказанным с учётом p-value.

# %% [markdown]
# ## 1. Изучить набор данных. Создать описание набора данных на русском языке. Описать признаки, используемые в наборе данных (включить полученные описания в отчёт).

# %% [markdown]
# 1. **Date** - Дата (ДД/ММ/ГГГГ).
# 2. **Time** - Время - (ЧЧ.ММ.СС).
# 3. **CO(GT)** - Почасовая усредненная концентрация СО в мг/м^3.
# 4. **PT08.S1(CO)** - Оксид олова. Почасовой усредненный отклик датчика.
# 5. **NMHX(GT)** - Почасовая усредненная общая концентрация Неметановых углеводородов в мкг / м^3.
# 6. **C6H6(GT)** - Почасовая усредненная концентрация бензола в мкг/м^3.
# 7. **PT08.S2(NMHC)** - Почасовой усредненный отклик сенсора.
# 8. **NOx(GT)** - Почасовая усредненная концентрация NOx в ppb.
# 9. **PT08.S3(NOx)** - Оксид вольфрама. Почасовой усредненный отклик датчика (Направленного на NOx).
# 10. **NO2(GT)** - Почасовая усредненная концентрация NO2 в микрог/м^3.
# 11. **PT08.S4(NO2)** - Оксид вольфрама. Почасовой усредненный отклик датчика (направленного на NO2).
# 12. **PT08.S5(O3)** - Оксид индия.
# 13. **T** - Температура в °C.
# 14. **RH** - Относительная Влажность Воздуха (%).
# 15. **AH** - Абсолютная влажность воздуха.

# %% [markdown]
# ## 2. Удалите дубликаты строк в наборе данных; приведите размер набора данных до и после данной операции;

# %%
import pandas as pd
df = pd.read_csv('AirQualityUCI.csv',sep=';', decimal=',')
df.drop(['Unnamed: 15', 'Unnamed: 16'], axis = 1, inplace = True)
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
print('Количество строк до удаления дубликатов: ', len(df.index))
df.drop_duplicates(keep = False, inplace = True)
print('Количество строк после удаления дубликатов: ', len(df.index))
# Out:
# Количество строк до удаления дубликатов:  9471
# Количество строк после удаления дубликатов:  9357

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %% [markdown]
# ## 3. Выполните масштабирование количественных признаков; Постройте диаграммы BoxPlot для признаков до и после масштабирования. Выберите способ масштабирования (например, нормализацию или стандартизацию);

# %%
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

quantitative_df = df.drop(['Date', 'Time'], axis = 1)

# %%
sns.boxplot(data = quantitative_df, orient = 'h')
print('BoxPlot до масштабирования:')
# Out:
# BoxPlot до масштабирования:

# %%
scaler = MinMaxScaler()
scaler.fit(quantitative_df)
quantitative_df = scaler.transform(quantitative_df)

print('BoxPlot после масштабирования:')
sns.boxplot(data = quantitative_df, orient = 'h')
# Out:
# BoxPlot после масштабирования:

# %% [markdown]
# ## 4. Выполните замену категориальных признаков; выберите и обоснуйте способ замены;

# %%
categorial_columns = [i for i in df.columns if df[i].dtype.name == 'object']
print("Categorical: " + str(categorial_columns))
# Out:
# Categorical: ['Date', 'Time']

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['Date'] = pd.Series(label_encoder.fit_transform(df['Date']))
df['Time'] = pd.Series(label_encoder.fit_transform(df['Time']))
df
# Out:
#       Date  Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 0      114    18     2.6       1360.0     150.0      11.9         1046.0
# 1      114    19     2.0       1292.0     112.0       9.4          955.0
# 2      114    20     2.2       1402.0      88.0       9.0          939.0
# 3      114    21     2.2       1376.0      80.0       9.2          948.0
# 4      114    22     1.6       1272.0      51.0       6.5          836.0
# ...    ...   ...     ...          ...       ...       ...            ...
# 9352    43    10     3.1       1314.0    -200.0      13.5         1101.0
# 9353    43    11     2.4       1163.0    -200.0      11.4         1027.0
# 9354    43    12     2.4       1142.0    -200.0      12.4         1063.0
# 9355    43    13     2.1       1003.0    -200.0       9.5          961.0
# 9356    43    14     2.2       1071.0    -200.0      11.9         1047.0
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# ...

# %% [markdown]
# ## 5. Оцените корреляцию между признаков и удалите те признаки, которые коррелируют с наибольшим числом других;

# %%
corr_df = df.corr()
corr_df
# Out:
#                    Date      Time    CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# Date           1.000000  0.000806 -0.038054     0.015190  0.055764  0.035579
# Time           0.000806  1.000000  0.075984     0.196780  0.049371  0.046087
# CO(GT)        -0.038054  0.075984  1.000000     0.041411  0.128351 -0.031378
# PT08.S1(CO)    0.015190  0.196780  0.041411     1.000000  0.170007  0.852687
# NMHC(GT)       0.055764  0.049371  0.128351     0.170007  1.000000  0.037323
# C6H6(GT)       0.035579  0.046087 -0.031378     0.852687  0.037323  1.000000
# PT08.S2(NMHC)  0.011858  0.282315  0.029926     0.933102  0.110104  0.767433
# NOx(GT)        0.004858  0.225153  0.526451     0.277993 -0.004427 -0.001174
# PT08.S3(NOx)   0.041003 -0.256172 -0.089981     0.087019  0.048821  0.512193
# NO2(GT)        0.027495  0.219483  0.671127     0.154030  0.103307 -0.010992
# PT08.S4(NO2)   0.001698  0.147978 -0.073724     0.845149  0.162680  0.774673
# ...

# %%
sns.heatmap(corr_df, annot = True, fmt = '.1f', linewidths = .5)

# %% [markdown]
# ## 6. Заполните пропущенные значения в данных;

# %%
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %% [markdown]
# ***В данном наборе данных нет пропущенных значений***

# %% [markdown]
# ## 7. Решите поставленную задачу регрессии в соответствии с заданием. При подборе параметров метода принятия решения (метода регрессии) используйте перекрёстную проверку (изучите возможные для изменения параметры метода регрессии). Вычислите точность решения задачи, вычислив разницу между реальным значением и предсказанным. Вычислите коэффициент корреляции (Пирсона, Спирмена) между реальным значением и предсказанным с учётом p-value.

# %% [markdown]
# ***Линейная регрессия, LASSO регуляризатор***

# %%
import numpy as np
import warnings
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import LinearSVC
from scipy.stats import pearsonr, spearmanr

warnings.filterwarnings('ignore')

quantitative_df = df.drop(['Date', 'Time'], axis = 1)
X_data, Y_data = quantitative_df.drop(columns='NO2(GT)', axis=1).values, quantitative_df['NO2(GT)']
x_train, x_test, y_train, y_test = train_test_split(X_data, Y_data, test_size=0.3)

lasso = Lasso()
params = {'alpha': np.arange(0.01, 1, 0.005)}
grid_search = GridSearchCV(lasso, params)
grid_search.fit(x_train, y_train)
best = grid_search.best_estimator_.alpha

lasso = Lasso(alpha=best)
lasso.fit(x_train,y_train)
predict_regulate = lasso.predict(x_test)
pearson, P_p_value = pearsonr(predict_regulate, y_test)
spearman, S_p_value = spearmanr(predict_regulate, y_test)

print("Spearman correlation: ", spearman)
print("Pearson correlation: ", pearson)
print('')

if P_p_value < 0.05:
    print('p_value (Pearson) is good')
else:
    print('p_value (Pearson) is not good')
if S_p_value < 0.05:
    print('p_value (Spearman) is good')
else:
    print('p_value (Spearman) is not good')
# Out:
# Spearman correlation:  0.8674288201895263
# Pearson correlation:  0.902136359497887
#
# p_value (Pearson) is good
# p_value (Spearman) is good

# %% [markdown]
# ***Линейная регрессия, RIDGE регуляризатор***

# %%
from sklearn.linear_model import LinearRegression, Ridge

reg = Ridge()
params = {'alpha': np.arange(0, 3, 0.05)}
reg_grid = GridSearchCV(reg, params)
reg_grid.fit(x_train, y_train)
best_alpha = reg_grid.best_estimator_.alpha

reg = Ridge(alpha=best_alpha)
reg.fit(x_train,y_train)
pred_reg = reg.predict(x_test)

pearson, P_p_value = pearsonr(pred_reg, y_test)
spearman, S_p_value = spearmanr(pred_reg, y_test)

print('Spearman correlation: ', spearman)
print('Pearson correlation: ', pearson)
print('')

if P_p_value < 0.05:
    print('p_value (Pearson) is good')
else:
    print('p_value (Pearson) is not good')
if S_p_value < 0.05:
    print('p_value (Spearman) is good')
else:
    print('p_value (Spearman) is not good')
# Out:
# Spearman correlation:  0.8686692206088722
# Pearson correlation:  0.902676444523456
#
# p_value (Pearson) is good
# p_value (Spearman) is good
