# %% [markdown]
# ### Мигунов Николай
# ## Лабораторная работа 1
#    # вариант 6
#         6. Индекс счастья
# 1. Визуализируйте корреляции между признаками, находящимися в наборе данных (heatmap). Сделайте выводы.
# 2. Постройте график счастья по регионам, страны на графике должны представляться отдельными точками.
# 3. Оцените количество счастья по годам по регионам.
# 4. Определите наиболее сильно изменяющиеся параметры по разным странам в разные годы.
# 5. Определите страны, появляющиеся и исчезающие в рейтинге стран.
# 6. Удалите строки с пропущенными значениями. Выведите размер набора данных до и после удаления.
# 7. Вычислите корреляцию Пирсона и Спирмена между признаками Trust.Government.Corruption и Family. Сравните полученные величины корреляции. Постройте гистограммы для указанных признаков. Оцените значение p-value.
# 8. Добавьте в набор данных признак, являющийся суммой двух других признаков.

# %%
import pandas as pd

# %%
df1 = pd.read_csv('2015.csv')
df1
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
df2 = pd.read_csv('2016.csv')
df2
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# 1              7.509                      7.428                      7.590
# 2              7.501                      7.333                      7.669
# 3              7.498                      7.421                      7.575
# 4              7.413                      7.351                      7.475
# ..               ...                        ...                        ...
# 152            3.484                      3.404                      3.564
# 153            3.360                      3.288                      3.432
# 154            3.303                      3.192                      3.414
# 155            3.069                      2.936                      3.202
# 156            2.905                      2.732                      3.078
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.44178  1.16374                   0.79504  0.57941
# 1                     1.52733  1.14524                   0.86303  0.58557
# 2                     1.42666  1.18326                   0.86733  0.56624
# 3                     1.57744  1.12690                   0.79579  0.59609
# 4                     1.40598  1.13464                   0.81091  0.57104
# ..                        ...      ...                       ...      ...
# 152                   0.39499  0.10419                   0.21028  0.39747
# 153                   0.38227  0.11037                   0.17344  0.16430
# 154                   0.28123  0.00000                   0.24811  0.34678
# 155                   0.74719  0.14866                   0.62994  0.06912
# 156                   0.06831  0.23442                   0.15747  0.04320
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.44453     0.36171            2.73939
# 1                          0.41203     0.28083            2.69463
# 2                          0.14975     0.47678            2.83137
# 3                          0.35776     0.37895            2.66465
# 4                          0.41004     0.25492            2.82596
# ..                             ...         ...                ...
# 152                        0.06681     0.20180            2.10812
# 153                        0.07112     0.31268            2.14558
# 154                        0.11587     0.17517            2.13540
# 155                        0.17233     0.48397            0.81789
# 156                        0.09419     0.20290            2.10404
#
# [157 rows x 13 columns]

# %%
df3 = pd.read_csv('2017.csv')
df3
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 0       7.479556                  1.616463  1.533524
# 1       7.462272                  1.482383  1.551122
# 2       7.385970                  1.480633  1.610574
# 3       7.426227                  1.564980  1.516912
# 4       7.410458                  1.443572  1.540247
# ..           ...                       ...       ...
# 150     3.398970                  0.368746  0.945707
# 151     3.260331                  0.777153  0.396103
# 152     3.236570                  0.511136  1.041990
# 153     2.735310                  0.091623  0.629794
# 154     2.521116                  0.000000  0.000000
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 0                    0.796667  0.635423    0.362012
# 1                    0.792566  0.626007    0.355280
# 2                    0.833552  0.627163    0.475540
# 3                    0.858131  0.620071    0.290549
# 4                    0.809158  0.617951    0.245483
# ..                        ...       ...         ...
# 150                  0.326425  0.581844    0.252756
# 151                  0.500533  0.081539    0.493664
# 152                  0.364509  0.390018    0.354256
# 153                  0.151611  0.059901    0.204435
# 154                  0.018773  0.270842    0.280876
#
#      Trust..Government.Corruption.  Dystopia.Residual
# 0                         0.315964           2.277027
# 1                         0.400770           2.313707
# 2                         0.153527           2.322715
# 3                         0.367007           2.276716
# 4                         0.382612           2.430182
# ..                             ...                ...
# 150                       0.455220           0.540061
# 151                       0.151347           1.061574
# 152                       0.066035           0.621130
# 153                       0.084148           1.683024
# 154                       0.056565           2.066005
#
# [155 rows x 12 columns]

# %% [markdown]
# 1. Визуализируйте корреляции между признаками, находящимися в наборе данных (heatmap). Сделайте выводы.

# %%
import seaborn as sb
# %matplotlib inline
sb.heatmap(df1.corr(), annot = True, fmt = '.1f', linewidths = .5)

# %%
import seaborn as sb
# %matplotlib inline
sb.heatmap(df2.corr(), annot = True, fmt = '.1f', linewidths = .5)

# %%
import seaborn as sb
# %matplotlib inline
sb.heatmap(df3.corr(), annot = True, fmt = '.1f', linewidths = .5)

# %%
happy = df1[['Country'] + ['Region'] + ['Happiness Rank'] + ['Happiness Score']]
happy.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427

# %% [markdown]
# 2. Постройте график счастья по регионам, страны на графике должны представляться отдельными точками.

# %%
import matplotlib.pyplot as plt
data = pd.DataFrame(happy.sort_values(by='Region', ascending=False))
data = data.reset_index(drop=True)
plt.ylabel('Happiness Score')
x = 0
region = data['Region'][0]
X = [0]
labels = [data['Region'][0]]
for i in range(0, happy.last_valid_index()+1):
    if region is not data['Region'][i]:
        labels.append(data['Region'][i])
        region = data['Region'][i]
        x = x + 1
        X.append(x)
    plt.plot(x, data['Happiness Score'][i], 'bo')
plt.xticks(X, labels, rotation='vertical')
plt.show()

# %%
happy = df2[['Country'] + ['Region'] + ['Happiness Rank'] + ['Happiness Score']]
happy.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413

# %%
import matplotlib.pyplot as plt
data = pd.DataFrame(happy.sort_values(by='Region', ascending=False))
data = data.reset_index(drop=True)
plt.ylabel('Happiness Score')
x = 0
region = data['Region'][0]
X = [0]
labels = [data['Region'][0]]
for i in range(0, happy.last_valid_index()+1):
    if region is not data['Region'][i]:
        labels.append(data['Region'][i])
        region = data['Region'][i]
        x = x + 1
        X.append(x)
    plt.plot(x, data['Happiness Score'][i], 'bo')
plt.xticks(X, labels, rotation='vertical')
plt.show()

# %% [markdown]
# 3. Оцените количество счастья по годам по регионам.

# %%
Df1 = df1.loc[:, ('Country', 'Region')]
Df2 = df2.loc[:, ('Country', 'Region')]
Df1_2 = Df1.merge(Df2, how='outer')
Df3 = df3.merge(Df1_2, on='Country')
pd.DataFrame({
    '2015': df1.groupby(['Region'])['Happiness Score'].mean(),
    '2016': df2.groupby(['Region'])['Happiness Score'].mean(),
    '2017': Df3.groupby(['Region'])['Happiness.Score'].mean(),
})
# Out:
#                                      2015      2016      2017
# Region
# Australia and New Zealand        7.285000  7.323500  7.299000
# Central and Eastern Europe       5.332931  5.370690  5.409931
# Eastern Asia                     5.626167  5.624167  5.496500
# Latin America and Caribbean      6.144682  6.101750  5.957818
# Middle East and Northern Africa  5.406900  5.386053  5.369684
# North America                    7.273000  7.254000  7.154500
# Southeastern Asia                5.317444  5.338889  5.444875
# Southern Asia                    4.580857  4.563286  4.628429
# Sub-Saharan Africa               4.202800  4.136421  4.111949
# Western Europe                   6.689619  6.685667  6.703714

# %% [markdown]
# 4. Определите наиболее сильно изменяющиеся параметры по разным странам в разные годы.

# %%
def changes(df, lb):
    ch = df.std() / df.mean()
    print('\n{}\n{}'.format(lb, ch.sort_values()[::-1]))

all = pd.concat([df1, df2, df3])

changes(df1, '2015')
changes(df2, '2016')
changes(df3, '2017')
changes(all, 'All')
# Out:
# 2015
# Trust (Government Corruption)    0.836930
# Happiness Rank                   0.575572
# Generosity                       0.533870
# Economy (GDP per Capita)         0.476425
# Health (Life Expectancy)         0.392026
# Standard Error                   0.358072
# Freedom                          0.351581
# Family                           0.274830
# Dystopia Residual                0.263724
# Happiness Score                  0.212996
# dtype: float64
#
# 2016
# Trust (Government Corruption)    0.806822
# Happiness Rank                   0.575659
# Generosity                       0.551263
# Economy (GDP per Capita)         0.432544
# Health (Life Expectancy)         0.411301
# Freedom                          0.392208
# Family                           0.336062
# Dystopia Residual                0.233132
# Lower Confidence Interval        0.217334
# Happiness Score                  0.212121
# Upper Confidence Interval        0.207315
# dtype: float64
#
# 2017
# Trust..Government.Corruption.    0.825702
# Happiness.Rank                   0.575497
# Generosity                       0.545927
# Health..Life.Expectancy.         0.429993
# Economy..GDP.per.Capita.         0.427323
# Freedom                          0.366934
# Dystopia.Residual                0.270251
# Family                           0.241621
# Whisker.low                      0.217864
# Happiness.Score                  0.211286
# Whisker.high                     0.205149
# dtype: float64
#
# All
# Trust..Government.Corruption.    0.825702
# Trust (Government Corruption)    0.821806
# Happiness.Rank                   0.575497
# Happiness Rank                   0.574710
# Generosity                       0.543026
# Economy (GDP per Capita)         0.456504
# Health..Life.Expectancy.         0.429993
# Economy..GDP.per.Capita.         0.427323
# Health (Life Expectancy)         0.405334
# Freedom                          0.373251
# Standard Error                   0.358072
# Family                           0.321814
# Dystopia.Residual                0.270251
# Dystopia Residual                0.252586
# Whisker.low                      0.217864
# Lower Confidence Interval        0.217334
# Happiness Score                  0.212222
# Happiness.Score                  0.211286
# Upper Confidence Interval        0.207315
# Whisker.high                     0.205149
# dtype: float64

# %% [markdown]
# 5. Определите страны, появляющиеся и исчезающие в рейтинге стран.

# %%
def diff(Df1, Df2):
    d = pd.merge(Df1, Df2, how='outer', indicator=True, on='Country')
    return d[d['_merge'] != 'both']

df1_2 = diff(df1, df2)
df1_3 = diff(df1, df3)
df2_3 = diff(df2, df3)

df_diff = pd.merge(pd.merge(df1_2, df1_3, how='outer'), df2_3, how='outer')
df_diff = df_diff['Country'].drop_duplicates()
df_diff
# Out:
# 0                         Oman
# 1            Somaliland region
# 2                   Mozambique
# 3                      Lesotho
# 4                    Swaziland
# 5                     Djibouti
# 6     Central African Republic
# 7                  Puerto Rico
# 8                       Belize
# 9                      Somalia
# 10           Somaliland Region
# 11                     Namibia
# 12                 South Sudan
# 13                      Taiwan
# 14                    Suriname
# 15                   Hong Kong
# 16                        Laos
# 17                     Comoros
# 18    Taiwan Province of China
# 20     Hong Kong S.A.R., China
# Name: Country, dtype: object

# %% [markdown]
# 6. Удалите строки с пропущенными значениями. Выведите размер набора данных до и после удаления.

# %%
print("Before:", df1.shape)
df = df1.dropna()
print("After:", df.shape)
# Out:
# Before: (158, 12)
# After: (158, 12)

# %% [markdown]
# 7. Вычислите корреляцию Пирсона и Спирмена между признаками Trust.Government.Corruption и Family. Сравните полученные величины корреляции. Постройте гистограммы для указанных признаков. Оцените значение p-value.

# %%
import scipy
p_corr, p_pval = scipy.stats.pearsonr(df3['Trust..Government.Corruption.'], df3['Family'])
s_corr, s_pval = scipy.stats.spearmanr(df3['Trust..Government.Corruption.'], df3['Family'])

labels = ('Pearson_Correlation', 'Spearman_Correlation')
plt.bar(range(2), [p_corr, s_corr], tick_label=labels)

print('Spearman p-value: {}\nPearson p-value: {}'.format(s_pval, p_pval))
# Out:
# Spearman p-value: 0.011338926895523417
# Pearson p-value: 0.0036996764406809946

# %% [markdown]
# 8. Добавьте в набор данных признак, являющийся суммой двух других признаков.

# %%
df3['Whisker.summ'] = df3['Whisker.high'] + df3['Whisker.low']
df3
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 0       7.479556                  1.616463  1.533524
# 1       7.462272                  1.482383  1.551122
# 2       7.385970                  1.480633  1.610574
# 3       7.426227                  1.564980  1.516912
# 4       7.410458                  1.443572  1.540247
# ..           ...                       ...       ...
# 150     3.398970                  0.368746  0.945707
# 151     3.260331                  0.777153  0.396103
# 152     3.236570                  0.511136  1.041990
# 153     2.735310                  0.091623  0.629794
# 154     2.521116                  0.000000  0.000000
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 0                    0.796667  0.635423    0.362012
# 1                    0.792566  0.626007    0.355280
# 2                    0.833552  0.627163    0.475540
# 3                    0.858131  0.620071    0.290549
# 4                    0.809158  0.617951    0.245483
# ..                        ...       ...         ...
# 150                  0.326425  0.581844    0.252756
# 151                  0.500533  0.081539    0.493664
# 152                  0.364509  0.390018    0.354256
# 153                  0.151611  0.059901    0.204435
# 154                  0.018773  0.270842    0.280876
#
#      Trust..Government.Corruption.  Dystopia.Residual  Whisker.summ
# 0                         0.315964           2.277027        15.074
# 1                         0.400770           2.313707        15.044
# 2                         0.153527           2.322715        15.008
# 3                         0.367007           2.276716        14.988
# 4                         0.382612           2.430182        14.938
# ..                             ...                ...           ...
# 150                       0.455220           0.540061         6.942
# 151                       0.151347           1.061574         6.924
# 152                       0.066035           0.621130         6.698
# 153                       0.084148           1.683024         5.810
# 154                       0.056565           2.066005         5.386
#
# [155 rows x 13 columns]
