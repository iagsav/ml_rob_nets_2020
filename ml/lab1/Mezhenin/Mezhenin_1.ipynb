# %% [markdown]
# # Вариант 3

# %%
import pandas as pd
cars_df = pd.read_csv(r'D:\ml\lb1\autos.csv', encoding='iso-8859-1')
cars_df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %% [markdown]
# ### 1. Удалите столбцы, ценность которых для оценки стоимости машины низка.

# %%
cars_df_dropped = cars_df.drop(['seller', 'monthOfRegistration', 'dateCreated', 'nrOfPictures', 'postalCode', 'lastSeen', 
                                'dateCrawled', 'abtest'], axis = 'columns')
cars_df_dropped
# Out:
#                                                 name offerType  price  \
# 0                                         Golf_3_1.6   Angebot    480
# 1                               A5_Sportback_2.7_Tdi   Angebot  18300
# 2                     Jeep_Grand_Cherokee_"Overland"   Angebot   9800
# 3                                 GOLF_4_1_4__3TÜRER   Angebot   1500
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic   Angebot   3600
# ...                                              ...       ...    ...
# 371523                    Suche_t4___vito_ab_6_sitze   Angebot   2200
# 371524         Smart_smart_leistungssteigerung_100ps   Angebot   1199
# 371525            Volkswagen_Multivan_T4_TDI_7DC_UY2   Angebot   9200
# 371526                        VW_Golf_Kombi_1_9l_TDI   Angebot   3400
# 371527  BMW_M135i_vollausgestattet_NP_52.720____Euro   Angebot  28990
#
#        vehicleType  yearOfRegistration    gearbox  powerPS        model  \
# ...

# %% [markdown]
# ### 2. Удалите повторяющиеся строки, строки содержащие пропуски в данных. Выведите размер набора данных до и после удаления

# %%
cars_old_shape = cars_df_dropped.shape[0]+1
cars_df_dropped.drop_duplicates(keep=False, inplace=True)
cars_df_dropped
# Out:
#                                                 name offerType  price  \
# 0                                         Golf_3_1.6   Angebot    480
# 1                               A5_Sportback_2.7_Tdi   Angebot  18300
# 2                     Jeep_Grand_Cherokee_"Overland"   Angebot   9800
# 3                                 GOLF_4_1_4__3TÜRER   Angebot   1500
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic   Angebot   3600
# ...                                              ...       ...    ...
# 371523                    Suche_t4___vito_ab_6_sitze   Angebot   2200
# 371524         Smart_smart_leistungssteigerung_100ps   Angebot   1199
# 371525            Volkswagen_Multivan_T4_TDI_7DC_UY2   Angebot   9200
# 371526                        VW_Golf_Kombi_1_9l_TDI   Angebot   3400
# 371527  BMW_M135i_vollausgestattet_NP_52.720____Euro   Angebot  28990
#
#        vehicleType  yearOfRegistration    gearbox  powerPS        model  \
# ...

# %%
cars_with_empty_cells_df = cars_df_dropped.copy()
cars_df_dropped.dropna(axis=0, how='any', inplace=True)
cars_df_dropped
# Out:
#                                                      name offerType  price  \
# 3                                      GOLF_4_1_4__3TÜRER   Angebot   1500
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic   Angebot   3600
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...   Angebot    650
# 6                             Peugeot_206_CC_110_Platinum   Angebot   2200
# 7                            VW_Derby_Bj_80__Scheunenfund   Angebot      0
# ...                                                   ...       ...    ...
# 371518                          Bmw_320_D_DPF_Touring_!!!   Angebot   3999
# 371520                                       turbo_defekt   Angebot   3200
# 371524              Smart_smart_leistungssteigerung_100ps   Angebot   1199
# 371525                 Volkswagen_Multivan_T4_TDI_7DC_UY2   Angebot   9200
# 371527       BMW_M135i_vollausgestattet_NP_52.720____Euro   Angebot  28990
#
# ...

# %% [markdown]
# **До удаления строк**

# %%
cars_old_shape
# Out:
# 371529

# %% [markdown]
# **После удаления**

# %%
cars_df_dropped.shape[0]+1
# Out:
# 246150

# %% [markdown]
# ### 3. Удалите данные в строках, выходящие за некоторые пределы (год регистрации, цена, мощность двигателя). Выведите размер набора данных до и после удаления. Для оценки диапазонов значений признаков используйте BoxPlot.

# %%
cars_old_shape = cars_df_dropped.shape[0]+1
cars_condition_df = cars_df_dropped[(cars_df_dropped.price <= 80000) & (cars_df_dropped.price >= 25000) & (cars_df_dropped.yearOfRegistration <= 2010 ) & (cars_df_dropped.yearOfRegistration >= 2004) & (cars_df_dropped.powerPS >= 180) & (cars_df_dropped.powerPS <= 400)]
cars_df_dropped.drop(cars_condition_df.index, inplace=True)

# %% [markdown]
# **До удаления**

# %%
cars_old_shape
# Out:
# 246150

# %% [markdown]
# **После удаления**

# %%
cars_df_dropped.shape[0]+1
# Out:
# 244780

# %%
boxplot_all = cars_df_dropped.boxplot(column=['price','yearOfRegistration', 'powerPS'])
boxplot_all

# %%
boxplot_price = cars_df_dropped.boxplot(column=['price'])
boxplot_price

# %%
boxplot_year = cars_df_dropped.boxplot(column=['yearOfRegistration'])
boxplot_year

# %%
boxplot_power = cars_df_dropped.boxplot(column=['powerPS'])
boxplot_power

# %% [markdown]
# ### 4. Заполнить пропущенные данные в строковых полях.

# %%
cars_with_empty_cells_df = cars_with_empty_cells_df.fillna('empty')

# %%
cars_with_empty_cells_df = cars_with_empty_cells_df.isnull().sum()
print('Number of empty cells: ',cars_with_empty_cells_df.sum().sum())
# Out:
# Number of empty cells:  0

# %% [markdown]
# ### 5. Постройте гистограмму по маркам автомобилей, типам кузова и используемому топливу.

# %%
import matplotlib.pyplot as plt
import numpy as np
tmp_df = cars_df_dropped.copy()
brand_array = tmp_df.groupby(by='brand').brand.count().sort_values(ascending=False)
plt.bar(np.arange(5),brand_array.head())
plt.xticks(np.arange(len(brand_array.head())),brand_array.index)
plt.show()

# %%
brand_array = tmp_df.groupby(by='vehicleType').vehicleType.count().sort_values(ascending=False)
plt.bar(np.arange(5),brand_array.head())
plt.xticks(np.arange(len(brand_array.head())),brand_array.index)
plt.show()

# %%
brand_array = tmp_df.groupby(by='fuelType').fuelType.count().sort_values(ascending=False)
plt.bar(np.arange(5),brand_array.head())
plt.xticks(np.arange(len(brand_array.head())),brand_array.index)
plt.show()

# %% [markdown]
# ### 6. Добавьте в данные новый признак, который представляет собой длину названия автомобиля.

# %%
def count(name):
    return name.str.len()
symbols_count = cars_df_dropped['name'].astype(str)
symbols_count = count(symbols_count)

# %%
new_column = cars_df_dropped
new_column['name_length'] = symbols_count
new_column
# Out:
#                                                      name offerType  price  \
# 3                                      GOLF_4_1_4__3TÜRER   Angebot   1500
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic   Angebot   3600
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...   Angebot    650
# 6                             Peugeot_206_CC_110_Platinum   Angebot   2200
# 7                            VW_Derby_Bj_80__Scheunenfund   Angebot      0
# ...                                                   ...       ...    ...
# 371518                          Bmw_320_D_DPF_Touring_!!!   Angebot   3999
# 371520                                       turbo_defekt   Angebot   3200
# 371524              Smart_smart_leistungssteigerung_100ps   Angebot   1199
# 371525                 Volkswagen_Multivan_T4_TDI_7DC_UY2   Angebot   9200
# 371527       BMW_M135i_vollausgestattet_NP_52.720____Euro   Angebot  28990
#
# ...

# %% [markdown]
# ### 7. Постройте карту корреляций между признаками. Выведите также числовые значения признаков.

# %%
import seaborn as sns
correlation  = new_column.corr()
heatmap = sns.heatmap(correlation, annot=True)
heatmap
correlation
# Out:
#                        price  yearOfRegistration   powerPS  kilometer  \
# price               1.000000            0.009872  0.007984  -0.013475
# yearOfRegistration  0.009872            1.000000  0.094316  -0.388390
# powerPS             0.007984            0.094316  1.000000  -0.009960
# kilometer          -0.013475           -0.388390 -0.009960   1.000000
# name_length         0.001856            0.064664  0.015828  -0.035035
#
#                     name_length
# price                  0.001856
# yearOfRegistration     0.064664
# powerPS                0.015828
# kilometer             -0.035035
# name_length            1.000000

# %% [markdown]
# ### 8. Определите коэффициент корреляции Пирсона и Спирмена между стоимостью автомобиля и типом кузова. Оцените значение p-value. Постройте плотность распределения признаков.

# %%
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from sklearn.preprocessing import LabelEncoder

lblEnc = LabelEncoder()
vehicleCoder = pd.Series(lblEnc.fit_transform(new_column.vehicleType))
pearsoncoef = pearsonr(new_column.price,vehicleCoder)
spearmancoef = spearmanr(new_column.price,vehicleCoder)

print("Коэффициент корреляции Пирсона: ",pearsoncoef)
print("Коэффициент корреляции Спирмена: ",spearmancoef)

if (spearmancoef[1] < 0.05):
    print("Значимая вероятность ошибки")
else:
    print("Не значимая")

a_price = pd.Series(new_column.price)
a_price.plot.kde()
# Out:
# Коэффициент корреляции Пирсона:  (0.0001642996235798423, 0.9352136627239522)
# Коэффициент корреляции Спирмена:  SpearmanrResult(correlation=0.041005500407890916, pvalue=1.395924425229494e-91)
# Значимая вероятность ошибки

# %% [markdown]
# ### 9. Добавьте в набор данных признак, являющийся суммой двух других признаков.

# %%
new_feature = new_column
new_feature['sum_of_features'] = new_feature['brand'] + '/' + new_feature['model']
new_feature
# Out:
#                                                      name offerType  price  \
# 3                                      GOLF_4_1_4__3TÜRER   Angebot   1500
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic   Angebot   3600
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...   Angebot    650
# 6                             Peugeot_206_CC_110_Platinum   Angebot   2200
# 7                            VW_Derby_Bj_80__Scheunenfund   Angebot      0
# ...                                                   ...       ...    ...
# 371518                          Bmw_320_D_DPF_Touring_!!!   Angebot   3999
# 371520                                       turbo_defekt   Angebot   3200
# 371524              Smart_smart_leistungssteigerung_100ps   Angebot   1199
# 371525                 Volkswagen_Multivan_T4_TDI_7DC_UY2   Angebot   9200
# 371527       BMW_M135i_vollausgestattet_NP_52.720____Euro   Angebot  28990
#
# ...
