# %% [markdown]
# # Лабораторная работа №1 3 вариант
# - Удалите столбцы, ценность которых для оценки стоимости машины низка

# %%
import pandas as pd
autos_df = pd.read_csv('autos.csv',encoding = 'iso-8859-1')
print(autos_df.columns)
autos_df.drop(['lastSeen','nrOfPictures','dateCreated','postalCode','seller','dateCrawled'],axis = 'columns')
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')
#                                                 name offerType  price  \
# 0                                         Golf_3_1.6   Angebot    480
# 1                               A5_Sportback_2.7_Tdi   Angebot  18300
# 2                     Jeep_Grand_Cherokee_"Overland"   Angebot   9800
# 3                                 GOLF_4_1_4__3TÜRER   Angebot   1500
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic   Angebot   3600
# ...                                              ...       ...    ...
# 371523                    Suche_t4___vito_ab_6_sitze   Angebot   2200
# 371524         Smart_smart_leistungssteigerung_100ps   Angebot   1199
# 371525            Volkswagen_Multivan_T4_TDI_7DC_UY2   Angebot   9200
# 371526                        VW_Golf_Kombi_1_9l_TDI   Angebot   3400
# 371527  BMW_M135i_vollausgestattet_NP_52.720____Euro   Angebot  28990
#
#          abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0          test         NaN                1993    manuell        0
# 1          test       coupe                2011    manuell      190
# 2          test         suv                2004  automatik      163
# 3          test  kleinwagen                2001    manuell       75
# 4          test  kleinwagen                2008    manuell       69
# ...         ...         ...                 ...        ...      ...
# 371523     test         NaN                2005        NaN        0
# 371524     test      cabrio                2000  automatik      101
# 371525     test         bus                1996    manuell      102
# 371526     test       kombi                2002    manuell      100
# 371527  control   limousine                2013    manuell      320
#
#               model  kilometer  monthOfRegistration fuelType           brand  \
# 0              golf     150000                    0   benzin      volkswagen
# 1               NaN     125000                    5   diesel            audi
# 2             grand     125000                    8   diesel            jeep
# 3              golf     150000                    6   benzin      volkswagen
# 4             fabia      90000                    7   diesel           skoda
# ...             ...        ...                  ...      ...             ...
# 371523          NaN      20000                    1      NaN  sonstige_autos
# 371524       fortwo     125000                    3   benzin           smart
# 371525  transporter     150000                    3   diesel      volkswagen
# 371526         golf     150000                    6   diesel      volkswagen
# 371527      m_reihe      50000                    8   benzin             bmw
#
#        notRepairedDamage
# 0                    NaN
# 1                     ja
# 2                    NaN
# 3                   nein
# 4                   nein
# ...                  ...
# 371523               NaN
# 371524              nein
# 371525              nein
# 371526               NaN
# 371527              nein
#
# [371528 rows x 14 columns]

# %% [markdown]
# - Удалите повторяющиеся строки, строки содержащие пропуски в данных. Выведите размер набора данных до и после удаления.

# %%
print("Размер входных данных до удаления ",autos_df.shape[0])
#удаление повторов
nondup_autos_df = autos_df.drop_duplicates(['name','offerType','price','vehicleType','yearOfRegistration','gearbox','powerPS',
                          'model','kilometer','monthOfRegistration','fuelType','brand','notRepairedDamage'], keep = 'last')
#удаление строк с пропусками в данных
nondup_autos_df = nondup_autos_df.dropna()
print("Размер входных данных поесле удаления ",nondup_autos_df.shape[0])
# Out:
# Размер входных данных до удаления  371528
# Размер входных данных поесле удаления  254921

# %% [markdown]
# - Удалите данные в строках, выходящие за некоторые пределы (год регистрации, цена, мощность двигателя). Выведите размер набора данных до и после удаления. Для оценки диапазонов значений признаков используйте BoxPlot.

# %%
# %matplotlib inline
print("Размер входных данных до удаления ",autos_df.shape[0])
#print(autos_df.columns)
part_autos_df = autos_df[(autos_df['yearOfRegistration'] < 2004) &
                         (autos_df['yearOfRegistration'] > 1990) &
                         (autos_df['price'] > 1000) & (autos_df['price'] < 5000) &
                         (autos_df['powerPS'] > 150) & (autos_df['powerPS'] < 250)]
print("Размер входных данных поесле удаления ",part_autos_df.shape[0])
part_autos_df.boxplot(column = ['yearOfRegistration'])
# Out:
# Размер входных данных до удаления  371528
# Размер входных данных поесле удаления  12805

# %%
part_autos_df.boxplot(column = ['price'])

# %%
part_autos_df.boxplot(column = ['powerPS'])

# %% [markdown]
# - Заполнить пропущенные данные в строковых полях

# %%
filled_autos_df = nondup_autos_df.fillna('No info')
filled_autos_df
# Out:
#                 dateCrawled  \
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# 6       2016-04-01 20:48:51
# 7       2016-03-21 18:54:38
# ...                     ...
# 371520  2016-03-19 19:53:49
# 371521  2016-03-27 20:36:20
# 371524  2016-03-05 19:56:21
# 371525  2016-03-19 18:57:12
# 371527  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 3                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# 6                             Peugeot_206_CC_110_Platinum  privat   Angebot
# 7                            VW_Derby_Bj_80__Scheunenfund  privat   Angebot
# ...                                                   ...     ...       ...
# 371520                                       turbo_defekt  privat   Angebot
# 371521                 Opel_Zafira_1.6_Elegance_TÜV_12/16  privat   Angebot
# 371524              Smart_smart_leistungssteigerung_100ps  privat   Angebot
# 371525                 Volkswagen_Multivan_T4_TDI_7DC_UY2  privat   Angebot
# 371527       BMW_M135i_vollausgestattet_NP_52.720____Euro  privat   Angebot
#
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 3        1500     test  kleinwagen                2001    manuell       75
# 4        3600     test  kleinwagen                2008    manuell       69
# 5         650     test   limousine                1995    manuell      102
# 6        2200     test      cabrio                2004    manuell      109
# 7           0     test   limousine                1980    manuell       50
# ...       ...      ...         ...                 ...        ...      ...
# 371520   3200  control   limousine                2004    manuell      225
# 371521   1150  control         bus                2000    manuell        0
# 371524   1199     test      cabrio                2000  automatik      101
# 371525   9200     test         bus                1996    manuell      102
# 371527  28990  control   limousine                2013    manuell      320
#
#         ... kilometer  monthOfRegistration  fuelType       brand  \
# 3       ...    150000                    6    benzin  volkswagen
# 4       ...     90000                    7    diesel       skoda
# 5       ...    150000                   10    benzin         bmw
# 6       ...    150000                    8    benzin     peugeot
# 7       ...     40000                    7    benzin  volkswagen
# ...     ...       ...                  ...       ...         ...
# 371520  ...    150000                    5    benzin        seat
# 371521  ...    150000                    3    benzin        opel
# 371524  ...    125000                    3    benzin       smart
# 371525  ...    150000                    3    diesel  volkswagen
# 371527  ...     50000                    8    benzin         bmw
#
#        notRepairedDamage          dateCreated nrOfPictures  postalCode  \
# 3                   nein  2016-03-17 00:00:00            0       91074
# 4                   nein  2016-03-31 00:00:00            0       60437
# 5                     ja  2016-04-04 00:00:00            0       33775
# 6                   nein  2016-04-01 00:00:00            0       67112
# 7                   nein  2016-03-21 00:00:00            0       19348
# ...                  ...                  ...          ...         ...
# 371520                ja  2016-03-19 00:00:00            0       96465
# 371521              nein  2016-03-27 00:00:00            0       26624
# 371524              nein  2016-03-05 00:00:00            0       26135
# 371525              nein  2016-03-19 00:00:00            0       87439
# 371527              nein  2016-03-07 00:00:00            0       73326
#
#                    lastSeen length
# 3       2016-03-17 17:40:17     18
# 4       2016-04-06 10:17:21     30
# 5       2016-04-06 19:17:07     50
# 6       2016-04-05 18:18:39     27
# 7       2016-03-25 16:47:58     28
# ...                     ...    ...
# 371520  2016-03-19 20:44:43     12
# 371521  2016-03-29 10:17:23     34
# 371524  2016-03-11 18:17:12     37
# 371525  2016-04-07 07:15:26     34
# 371527  2016-03-22 03:17:10     44
#
# [254921 rows x 21 columns]

# %% [markdown]
# - Постройте гистограмму по маркам автомобилей, типам кузова и используемому топливу.

# %%
autos_df['brand'].hist(figsize = (30,10), xlabelsize = 10)

# %%
autos_df['vehicleType'].hist(figsize = (30,10), xlabelsize = 15)

# %%
autos_df['fuelType'].hist(figsize = (30,10), xlabelsize = 15)

# %% [markdown]
# - Добавьте в данные новый признак, который представляет собой длину названия автомобиля.

# %%
autos_df['length'] = autos_df['name'].str.len()
autos_df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0       privat   Angebot    480     test         NaN                1993
# 1       privat   Angebot  18300     test       coupe                2011
# 2       privat   Angebot   9800     test         suv                2004
# 3       privat   Angebot   1500     test  kleinwagen                2001
# 4       privat   Angebot   3600     test  kleinwagen                2008
# ...        ...       ...    ...      ...         ...                 ...
# 371523  privat   Angebot   2200     test         NaN                2005
# 371524  privat   Angebot   1199     test      cabrio                2000
# 371525  privat   Angebot   9200     test         bus                1996
# 371526  privat   Angebot   3400     test       kombi                2002
# 371527  privat   Angebot  28990  control   limousine                2013
#
#           gearbox  powerPS  ... kilometer  monthOfRegistration  fuelType  \
# 0         manuell        0  ...    150000                    0    benzin
# 1         manuell      190  ...    125000                    5    diesel
# 2       automatik      163  ...    125000                    8    diesel
# 3         manuell       75  ...    150000                    6    benzin
# 4         manuell       69  ...     90000                    7    diesel
# ...           ...      ...  ...       ...                  ...       ...
# 371523        NaN        0  ...     20000                    1       NaN
# 371524  automatik      101  ...    125000                    3    benzin
# 371525    manuell      102  ...    150000                    3    diesel
# 371526    manuell      100  ...    150000                    6    diesel
# 371527    manuell      320  ...     50000                    8    benzin
#
#                  brand notRepairedDamage          dateCreated nrOfPictures  \
# 0           volkswagen               NaN  2016-03-24 00:00:00            0
# 1                 audi                ja  2016-03-24 00:00:00            0
# 2                 jeep               NaN  2016-03-14 00:00:00            0
# 3           volkswagen              nein  2016-03-17 00:00:00            0
# 4                skoda              nein  2016-03-31 00:00:00            0
# ...                ...               ...                  ...          ...
# 371523  sonstige_autos               NaN  2016-03-14 00:00:00            0
# 371524           smart              nein  2016-03-05 00:00:00            0
# 371525      volkswagen              nein  2016-03-19 00:00:00            0
# 371526      volkswagen               NaN  2016-03-20 00:00:00            0
# 371527             bmw              nein  2016-03-07 00:00:00            0
#
#         postalCode             lastSeen length
# 0            70435  2016-04-07 03:16:57     10
# 1            66954  2016-04-07 01:46:50     20
# 2            90480  2016-04-05 12:47:46     30
# 3            91074  2016-03-17 17:40:17     18
# 4            60437  2016-04-06 10:17:21     30
# ...            ...                  ...    ...
# 371523       39576  2016-04-06 00:46:52     26
# 371524       26135  2016-03-11 18:17:12     37
# 371525       87439  2016-04-07 07:15:26     34
# 371526       40764  2016-03-24 12:45:21     22
# 371527       73326  2016-03-22 03:17:10     44
#
# [371528 rows x 21 columns]

# %% [markdown]
# - Постройте карту корреляций между признаками. Выведите также числовые значения признаков.

# %%
import seaborn as sns
sns.heatmap(autos_df.corr(), annot = True, fmt='.3f')
autos_df.corr()
# Out:
#                         price  yearOfRegistration   powerPS  kilometer  \
# price                1.000000           -0.000182  0.006850  -0.000635
# yearOfRegistration  -0.000182            1.000000  0.000351  -0.055319
# powerPS              0.006850            0.000351  1.000000  -0.010738
# kilometer           -0.000635           -0.055319 -0.010738   1.000000
# monthOfRegistration -0.002826           -0.011607  0.044358   0.001838
# nrOfPictures              NaN                 NaN       NaN        NaN
# postalCode          -0.003164           -0.001652  0.027113  -0.026694
# length              -0.000053            0.001982  0.010299  -0.021107
#
#                      monthOfRegistration  nrOfPictures  postalCode    length
# price                          -0.002826           NaN   -0.003164 -0.000053
# yearOfRegistration             -0.011607           NaN   -0.001652  0.001982
# powerPS                         0.044358           NaN    0.027113  0.010299
# kilometer                       0.001838           NaN   -0.026694 -0.021107
# monthOfRegistration             1.000000           NaN    0.014963  0.013950
# nrOfPictures                         NaN           NaN         NaN       NaN
# postalCode                      0.014963           NaN    1.000000 -0.011996
# length                          0.013950           NaN   -0.011996  1.000000

# %% [markdown]
# - Определите коэффициент корреляции Пирсона и Спирмена между стоимостью автомобиля и типом кузова. Оцените значение p-value. Постройте плотность распределения признаков.

# %%
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data_pr = pd.Series(le.fit_transform(filled_autos_df['price']))
data_vt = pd.Series(le.fit_transform(filled_autos_df['vehicleType']))
spearman = spearmanr(data_pr, data_vt)
print('Коэффициенты корелляции')
print('Пирсона - ', pearsonr(data_pr, data_vt))
print('Спирмена -', spearman)
if spearman[1] < 0.05:
    print("допустимое значение pvalue")
else:
    print("недопустимое значение pvalue")
filled_autos_df.price.plot.kde()
# Out:
# Коэффициенты корелляции
# Пирсона -  (-0.005122782003536357, 0.00969613330595244)
# Спирмена - SpearmanrResult(correlation=0.03786079449110319, pvalue=1.6385071177569834e-81)
# допустимое значение pvalue

# %% [markdown]
# - Добавьте в набор данных признак, являющийся суммой двух других признаков.

# %%
autos_df['dateOfRegistration'] = autos_df['yearOfRegistration'] + autos_df['monthOfRegistration']
autos_df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0       privat   Angebot    480     test         NaN                1993
# 1       privat   Angebot  18300     test       coupe                2011
# 2       privat   Angebot   9800     test         suv                2004
# 3       privat   Angebot   1500     test  kleinwagen                2001
# 4       privat   Angebot   3600     test  kleinwagen                2008
# ...        ...       ...    ...      ...         ...                 ...
# 371523  privat   Angebot   2200     test         NaN                2005
# 371524  privat   Angebot   1199     test      cabrio                2000
# 371525  privat   Angebot   9200     test         bus                1996
# 371526  privat   Angebot   3400     test       kombi                2002
# 371527  privat   Angebot  28990  control   limousine                2013
#
#           gearbox  powerPS  ... monthOfRegistration  fuelType           brand  \
# 0         manuell        0  ...                   0    benzin      volkswagen
# 1         manuell      190  ...                   5    diesel            audi
# 2       automatik      163  ...                   8    diesel            jeep
# 3         manuell       75  ...                   6    benzin      volkswagen
# 4         manuell       69  ...                   7    diesel           skoda
# ...           ...      ...  ...                 ...       ...             ...
# 371523        NaN        0  ...                   1       NaN  sonstige_autos
# 371524  automatik      101  ...                   3    benzin           smart
# 371525    manuell      102  ...                   3    diesel      volkswagen
# 371526    manuell      100  ...                   6    diesel      volkswagen
# 371527    manuell      320  ...                   8    benzin             bmw
#
#        notRepairedDamage          dateCreated nrOfPictures postalCode  \
# 0                    NaN  2016-03-24 00:00:00            0      70435
# 1                     ja  2016-03-24 00:00:00            0      66954
# 2                    NaN  2016-03-14 00:00:00            0      90480
# 3                   nein  2016-03-17 00:00:00            0      91074
# 4                   nein  2016-03-31 00:00:00            0      60437
# ...                  ...                  ...          ...        ...
# 371523               NaN  2016-03-14 00:00:00            0      39576
# 371524              nein  2016-03-05 00:00:00            0      26135
# 371525              nein  2016-03-19 00:00:00            0      87439
# 371526               NaN  2016-03-20 00:00:00            0      40764
# 371527              nein  2016-03-07 00:00:00            0      73326
#
#                    lastSeen  length dateOfRegistration
# 0       2016-04-07 03:16:57      10               1993
# 1       2016-04-07 01:46:50      20               2016
# 2       2016-04-05 12:47:46      30               2012
# 3       2016-03-17 17:40:17      18               2007
# 4       2016-04-06 10:17:21      30               2015
# ...                     ...     ...                ...
# 371523  2016-04-06 00:46:52      26               2006
# 371524  2016-03-11 18:17:12      37               2003
# 371525  2016-04-07 07:15:26      34               1999
# 371526  2016-03-24 12:45:21      22               2008
# 371527  2016-03-22 03:17:10      44               2021
#
# [371528 rows x 22 columns]
